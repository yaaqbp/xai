# %%
colors = ["#8bdcbe","#f05a71",  "#46bac2", "#ae2c87", "#ffa58c", "#4378bf"]

# %%
labels1 = ["Changed correctly", "Changed incorrectly"]
labels2 = ["Correct", "Incorrect", "Changed correctly", "Changed incorrectly"]

# %%
lst1 = [76, 24]
lst2 = [31,41,21,7]

# %%
dct.keys()
# Out:
# dict_keys([41, 31, 21, 7])

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
fig.dpi = 300
ax = plt.pie(lst2, labels = labels2, 
        colors = colors[0:5], 
        autopct='%.0f%%', 
        startangle = 90,
        counterclock = False)
#plt.title('Wyniki ankiety')
plt.savefig('pie_chart_5.png')

# %%
fig, ax = plt.subplots()
fig.dpi = 300
ax = plt.pie(lst1, labels = labels1, colors = colors[0:2], autopct='%.0f%%', startangle = 90, counterclock = False)

plt.savefig('pie_chart_2.png')
